# %% [markdown]
# _________________

# %% [markdown]
# ## **Assignment 3**
#
# 1. Load both CSVs.
# 2. Store loads and prices into lists.
# 3. Write a function to compute.
# 4. Hourly bill
# 5. Total bill

# %%
import csv

# %%
with open(r"C:\Users\Muhib Ur-Rahman\Desktop\intro to ai\Assignment no 3 load.csv") as csvfile_1:
    reader_1=csv.reader(csvfile_1)
    load=[]
    for index, R_1 in enumerate(reader_1):
        if index==0:
            continue
        load.append(float(R_1[1]))
load
# Out:
# [200.0, 300.0, 500.0, 700.0, 600.0, 400.0, 800.0, 700.0, 600.0, 500.0]

# %%
with open(r"C:\Users\Muhib Ur-Rahman\Desktop\intro to ai\Assignment no  3 price.csv") as csvfile_2:
    reader_2=csv.reader(csvfile_2)
    
    price=[]
    for index, R_2 in enumerate(reader_2):
        if index==0:
            continue
        price.append(float(R_2[1]))
price
# Out:
# [40.0, 40.0, 40.0, 40.0, 40.0, 40.0, 40.0, 40.0, 40.0, 40.0]

# %% [markdown]
# we want to convert wat hour to killo wat hour the in down code we convert the wat hour to killo wat hour

# %%
killo_watt_hour=[x/1000 for x in load] 
killo_watt_hour
# Out:
# [0.2, 0.3, 0.5, 0.7, 0.6, 0.4, 0.8, 0.7, 0.6, 0.5]

# %% [markdown]
# _____________

# %% [markdown]
# ### 3. Write a function to compute.
#
# *3.1. Hourly bill*
#
# *3.2. Total bill*

# %%
def hourly_bill(price,killo_watt_hour):
    bill=[]
    
    for k in range(len(load)):
        bill.append(price[k]*killo_watt_hour[k])   
    return bill
bill=(hourly_bill(price,killo_watt_hour))

# %% [markdown]
#  Hourly bill

# %%
for i in range(len(load)):
    print(f'The bill number {i+1} is: {bill[i]}')
# Out:
# The bill number 1 is: 8.0
# The bill number 2 is: 12.0
# The bill number 3 is: 20.0
# The bill number 4 is: 28.0
# The bill number 5 is: 24.0
# The bill number 6 is: 16.0
# The bill number 7 is: 32.0
# The bill number 8 is: 28.0
# The bill number 9 is: 24.0
# The bill number 10 is: 20.0

# %% [markdown]
#  Total bill

# %%
print(f'the total bill is: {sum(bill)}')
# Out:
# the total bill is: 212.0

# %% [markdown]
# _________________
