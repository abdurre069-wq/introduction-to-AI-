# %% [markdown]
# ### **Lab work tasks**

# %% [markdown]
# ### 1)  Smart Home Energy Meter:-
# A smart home meter logs real-time energy usage
# {    "time": "18:32",
#     "grid_power": 720,
#     "solar_power": 340,
#     "battery_soc": 67,
#     "appliance_status": {"AC": "OFF", "Fridge": "ON", "Motor": "OFF"}}
# 1.	Print the "grid_power" value.
# 2.	Add a new appliance "TV": "ON" inside "appliance_status".
# 3.	Change "battery_soc" to 72.
# 4.	Check if "solar_power" exists in the dictionary.
# 5.	Delete the "Motor" key from "appliance_status".

# %%
meter = {
    "time": "18:32",
    "grid_power": 720,
    "solar_power": 340,
    "battery_soc": 67,
    "appliance_status": {"AC": "OFF", "Fridge": "ON", "Motor": "OFF"}
}

# %%
print (meter["grid_power"])
# Out:
# 720

# %%
meter["appliance_status"]["TV"] = "ON"

# %%
print(meter["appliance_status"])
# Out:
# {'AC': 'OFF', 'Fridge': 'ON', 'TV': 'ON'}

# %%
meter["battery_soc"] = 72

# %%
"solar_power" in meter
# Out:
# True

# %%
del meter["appliance_status"]["Motor"]

# %%
print(meter)
# Out:
# {'time': '18:32', 'grid_power': 720, 'solar_power': 340, 'battery_soc': 72, 'appliance_status': {'AC': 'OFF', 'Fridge': 'ON', 'TV': 'ON'}}

# %% [markdown]
# ### 2)  **University Student Record**
# A system stores basic info about a student:
# {  "name": "Ali Khan",
#     "roll_no": "EE-22-045",
#     "gpa": 3.41,
#     "courses": ["Circuit Analysis", "Linear Algebra", "Python"],
#     "attendance": {"Circuit Analysis": 92, "Linear Algebra": 88, "Python": 96}}
# 1.	Print the student’s GPA.
# 2.	Add a new course "Digital Logic" with attendance 90.
# 3.	Update "Linear Algebra" attendance to 91.
# 4.	Check if the key "gpa" exists.

# %%
student = {
    "name": "Ali Khan",
    "roll_no": "EE-22-045",
    "gpa": 3.41,
    "courses": ["Circuit Analysis", "Linear Algebra", "Python"],
    "attendance": {
        "Circuit Analysis": 92,
        "Linear Algebra": 88,
        "Python": 96
    }
}

# %%
print( "GPA:",student["gpa"])
# Out:
# GPA: 3.41

# %%
student["courses"].append("Digital Logic")
student["attendance"]["Digital Logic"] = 90

# %%
print("Updated courses:", student["courses"])
print("Updated attendance:", student["attendance"])
# Out:
# Updated courses: ['Circuit Analysis', 'Linear Algebra', 'Python', 'Digital Logic']
# Updated attendance: {'Circuit Analysis': 92, 'Linear Algebra': 91, 'Python': 96, 'Digital Logic': 90}

# %%
student["attendance"]["Linear Algebra"] = 91
print("Updated Linear Algebra attendance:", student["attendance"]["Linear Algebra"])
# Out:
# Updated Linear Algebra attendance: 91

# %%
print("Does 'gpa' exist?", "gpa" in student)
# Out:
# Does 'gpa' exist? True

# %% [markdown]
# ### **3)  Weather Monitoring Station**
# Hourly weather data is stored as a dictionary:
# {   "hour": 14,
#     "temperature": 33.8,
#     "humidity": 52,
#     "wind": {"speed": 12, "direction": "NE"},
#     "alerts": []}
#
# 1.	Print the wind direction.
# 2.	Add a new alert "High Temperature".
# 3.	Change the wind speed to 15.
# 4.	Use .keys() to list all top-level keys.
# 5.	Remove "humidity" using .pop().

# %%
weather={ "hour": 14, "temperature": 33.8, "humidity": 52, "wind": {"speed": 12, "direction": "NE"}, "alerts": []}

# %%
print("Wind Direction:", wheather["wind"]["direction"])
# Out:
# Wind Direction: NE

# %%
weather["alerts"].append("High Temperature")
print("Updated Alerts:", weather["alerts"])
# Out:
# Updated Alerts: ['High Temperature', 'High Temperature']

# %%
weather["wind"]["speed"] = 15
print("Updated Wind Speed:", weather["wind"]["speed"])
# Out:
# Updated Wind Speed: 15

# %%
print("All Top-Level Keys:", list(weather.keys()))
# Out:
# All Top-Level Keys: ['hour', 'temperature', 'humidity', 'wind', 'alerts']

# %%
print("All Top-Level Keys:", list(weather.values()))
# Out:
# All Top-Level Keys: [14, 33.8, 52, {'speed': 15, 'direction': 'NE'}, ['High Temperature']]

# %%
removed_value = weather.pop("humidity")
print("Removed Humidity Value:", removed_value)
# Out:
# Removed Humidity Value: 52

# %%
print("Final Weather Dictionary:", weather)
# Out:
# Final Weather Dictionary: {'hour': 14, 'temperature': 33.8, 'wind': {'speed': 15, 'direction': 'NE'}, 'alerts': ['High Temperature']}

# %% [markdown]
# ### **4)  Inventory System for Electronics Shop**
# A shop tracks an item in its inventory:
# {
#     "item_id": 1042,
#     "name": "PWM Solar Charge Controller",
#     "stock": 18,
#     "price": 2500,
#     "features": {"voltage": "12/24V", "current": "20A", "brand": "SolarTech"}
# }
# 1.	Print the brand of the controller.
# 2.	Reduce the stock by 2 and update the dictionary.
# 3.	Add a new feature "warranty": "1 year".
# 4.	Check if "price" exists in the dictionary.
# 5.	Merge another dictionary {"discount": 10} into the inventory item.

# %%
inventory = {
    "item_id": 1042,
    "name": "PWM Solar Charge Controller",
    "stock": 18,
    "price": 2500,
    "features": {"voltage": "12/24V", "current": "20A", "brand": "SolarTech"}
}

# %%
print("Brand:", inventory["features"]["brand"])
# Out:
# Brand: SolarTech

# %%
inventory["stock"] -= 2
print("Updated Stock:", inventory["stock"])
# Out:
# Updated Stock: 16

# %%
inventory["features"]["warranty"] = "1 year"
print("Updated Features:", inventory["features"])
# Out:
# Updated Features: {'voltage': '12/24V', 'current': '20A', 'brand': 'SolarTech', 'warranty': '1 year'}

# %%
print("Does 'price' exist?", "price" in inventory)
# Out:
# Does 'price' exist? True

# %%
print("Final Inventory Dictionary:", inventory)
# Out:
# Final Inventory Dictionary: {'item_id': 1042, 'name': 'PWM Solar Charge Controller', 'stock': 16, 'price': 2500, 'features': {'voltage': '12/24V', 'current': '20A', 'brand': 'SolarTech', 'warranty': '1 year'}}

# %% [markdown]
# ### **5)  Hospital Patient Monitoring System**
# Patient vitals are recorded every 10 minutes:
# {
#     "id": 907,
#     "name": "Faisal",
#     "heart_rate": 82,
#     "oxygen_level": 97,
#     "medications": {"aspirin": "8AM", "vitamin_D": "12PM"}
# }
# 1)	Print the oxygen level.
# 2)	Add a new medication "antibiotic": "6PM".
# 3)	Update heart rate to 78.
# 4)	Get the medication schedule for "insulin" using .get() with default "Not Prescribed".
# 5)	Use .items() to print all key-value pairs.

# %%
patient = {
    "id": 907,
    "name": "Faisal",
    "heart_rate": 82,
    "oxygen_level": 97,
    "medications": {"aspirin": "8AM", "vitamin_D": "12PM"}
}

# %%
print("Oxygen Level:", patient["oxygen_level"])
# Out:
# Oxygen Level: 97

# %%
patient["medications"]["antibiotic"] = "6PM"
print("Updated Medications:", patient["medications"])
# Out:
# Updated Medications: {'aspirin': '8AM', 'vitamin_D': '12PM', 'antibiotic': '6PM'}

# %%
patient["heart_rate"] = 78
print("Updated Heart Rate:", patient["heart_rate"])
# Out:
# Updated Heart Rate: 78

# %%
insulin_schedule = patient["medications"].get("insulin", "Not Prescribed")
print("Insulin Schedule:", insulin_schedule)
# Out:
# Insulin Schedule: Not Prescribed

# %%
print("All Patient Info:")
for key, value in patient.items():
    print(f"{key}: {value}")
# Out:
# All Patient Info:
# id: 907
# name: Faisal
# heart_rate: 78
# oxygen_level: 97
# medications: {'aspirin': '8AM', 'vitamin_D': '12PM', 'antibiotic': '6PM'}
